# %% [markdown]
# # chapter 2 exercises
#
# ## 1) a coin with probability of heads θ is indepently flipped n times, after which θ is estimated by:
#
# ![image.png](attachment:image.png)
#
#
# ## with s equal the number of heads observed.
#
# ### a) what are the bias and variance of  θhat ?

# %% [markdown]
# our estimator is that:
# ![image.png](attachment:image.png)

# %% [markdown]
# bias is the expected - the real
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Variance
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Import libraries that we'll need...
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.utils import resample
import matplotlib
#from statsmodels.regression.linear_model import OLS
#from statsmodels.tools.tools import add_constant
#from statsmodels.nonparametric.smoothers_lowess import lowess

# new imports for polynomial regresion
#https://ostwalprasad.github.io/machine-learning/Polynomial-Regression-using-statsmodel.html
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ### 2) Supplement Table 2.1 with entries for trimmed means, trim proportions 0.1, 0.2, 0.3, 0.4.
#
# (winsorize with this values)

# %% [markdown]
# ### 3) Page 14 presents two definitions of frequentism, one in terms of probabilistic accuracy and one in terms of an infinite sequence of future trials. Give a heuristic argument relating the two.

# %% [markdown]
# ### 4) . Suppose that in (2.15) we plugged in ˆσ to get an approximate 95% normal theory hypothesis test for H0 : θ = 0. How would it compare with the student-t hypothesis test?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5) Recompute the Neyman–Pearson alpha-beta curve in Figure 2.2, now with n = 20. In qualitative terms, how does it compare with the n = 10 curve?
