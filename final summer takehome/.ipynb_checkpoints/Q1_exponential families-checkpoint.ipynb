# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import gammaln
from scipy.optimize import minimize
from scipy import integrate

# %%
gfr_data = pd.read_csv('../data/gfr.csv')

# %%
gfr_data['gfr'].plot(kind='hist', figsize=(10,5))

# %%
freqs, bins = np.histogram(gfr_data, bins=20)

# %%
plt.figure(figsize=(20,10))
plt.bar(bins[:-1], freqs, width=4)
# Out:
# <BarContainer object of 20 artists>

# %%
data_median = gfr_data.median()[0]
gfr_data['gfr'] = gfr_data['gfr'] / (data_median)
bins = bins / (data_median)

# %%
plt.figure(figsize=(20,10))
plt.bar(bins[:-1], freqs, width=0.08)
# Out:
# <BarContainer object of 20 artists>

# %%
gfr_data['gfr_2'] = gfr_data['gfr'] ** 2
gfr_data['gfr_3'] = gfr_data['gfr'] ** 3
gfr_data['gfr_4'] = gfr_data['gfr'] ** 4
gfr_data['gfr_5'] = gfr_data['gfr'] ** 5
gfr_data['gfr_6'] = gfr_data['gfr'] ** 6
gfr_data['gfr_7'] = gfr_data['gfr'] ** 7
gfr_data
# Out:
#           gfr     gfr_2     gfr_3      gfr_4      gfr_5      gfr_6       gfr_7
# 0    2.076923  4.313609  8.959035  18.607227  38.645778  80.264309  166.702796
# 1    1.750000  3.062500  5.359375   9.378906  16.413086  28.722900   50.265076
# 2    1.192308  1.421598  1.694982   2.020940   2.409582   2.872963    3.425456
# 3    1.134615  1.287352  1.460649   1.657275   1.880370   2.133497    2.420698
# 4    1.615385  2.609467  4.215294   6.809320  10.999671  17.768700   28.703285
# ..        ...       ...       ...        ...        ...        ...         ...
# 206  0.538462  0.289941  0.156122   0.084066   0.045266   0.024374    0.013125
# 207  0.634615  0.402737  0.255583   0.162197   0.102933   0.065323    0.041455
# 208  0.673077  0.453033  0.304926   0.205238   0.138141   0.092980    0.062582
# 209  0.923077  0.852071  0.786527   0.726025   0.670177   0.618625    0.571038
# 210  0.596154  0.355399  0.211873   0.126309   0.075299   0.044890    0.026761
#
# [211 rows x 7 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = len(gfr_data['gfr'])
suff_stats = np.array([gfr_data['gfr'].mean(), 
                       (gfr_data['gfr_2']).mean() ,
                       (gfr_data['gfr_3']).mean(),
                       (gfr_data['gfr_4']).mean(),
                       (gfr_data['gfr_5']).mean(),
                       (gfr_data['gfr_6']).mean(),
                       (gfr_data['gfr_7']).mean()])
suff_stats, n
# Out:
# (array([1.04356544, 1.15832258, 1.37524484, 1.75618057, 2.41951239,
#         3.59098452, 5.70419479]),
#  211)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def psi_func(alpha_0, alpha_1, alpha_2, alpha_3, alpha_4, alpha_5, alpha_6):
    
    f = lambda x: np.exp(alpha_0 * x + alpha_1 * x ** 2 + alpha_2 * x ** 3
                        + alpha_3 * x ** 4 + alpha_4 * x ** 5 + alpha_5 * x ** 6 + alpha_6 * x ** 7)
    integ_val = integrate.quad(f, 0.4, 2.1)[0] #integrate over the sampel space (see abobe hist)
    psi_val = np.log(integ_val)
    
    return psi_val

# %%
def psi_2p_func(alpha_0, alpha_1):
    
    f = lambda x: np.exp(alpha_0 * x + alpha_1 * x ** 2)
    integ_val = integrate.quad(f, 0.4, 2.1)[0] #integrate over the sampel space (see abobe hist)
    psi2_val = np.log(integ_val)
    
    return psi2_val

# %%
def exp_family_negative_loglik(alpha_0, alpha_1, alpha_2, alpha_3, alpha_4, alpha_5, alpha_6, n , y_bar):
    
    f = lambda x: np.exp(alpha_0 * x + alpha_1 * x ** 2 + + alpha_2 * x ** 3
                        + alpha_3 * x ** 4 + alpha_4 * x ** 5 + alpha_5 * x ** 6 + alpha_6 * x ** 7)
    integ_val = integrate.quad(f, 0.4, 2.1)[0] #integrate over the sampel space (see abobe hist)
    psi = np.log(integ_val)
    loglik = n * (alpha_0 * y_bar[0] + alpha_1 * y_bar[1] + alpha_2 * y_bar[2] + alpha_3 * y_bar[3] 
                  + alpha_4 * y_bar[4] + alpha_5 * y_bar[5] + alpha_6 * y_bar[6] - psi)
    
    return -loglik

# %%
def exp_family_negative_loglik_2_par(alpha_0, alpha_1, n , y_bar):
    
    f = lambda x: np.exp(alpha_0 * x + alpha_1 * x ** 2)
    integ_val = integrate.quad(f, 0.4, 2.1)[0] #integrate over the sampel space (see abobe hist)
    psi_2p = np.log(integ_val)
    loglik = n * (alpha_0 * y_bar[0] + alpha_1 * y_bar[1] - psi_2p)
    
    return -loglik

# %%
minimize(lambda theta: exp_family_negative_loglik(theta[0], theta[1], theta[2], theta[3],
                                                              theta[4], theta[5], theta[6], n, suff_stats), 
                     (0,0,0,0,0,0,0), method='L-BFGS-B')
# Out:
#       fun: -5.76919912370907
#  hess_inv: <7x7 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00048725, -0.00026237,  0.00056222,  0.00179909,  0.00056222,
#         0.00116192, -0.00086207])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 656
#       nit: 69
#    status: 0
#   success: True
#         x: array([ 28.31782149,  -1.02455524, -16.19914411,  -3.12747382,
#         12.96569166,  -6.3103605 ,   1.00372326])

# %%
theta_hat = minimize(lambda theta: exp_family_negative_loglik(theta[0], theta[1], theta[2], theta[3],
                                                              theta[4], theta[5], theta[6], n, suff_stats), 
                     (0,0,0,0,0,0,0), method='L-BFGS-B')['x']

# %%
minimize(lambda theta: exp_family_negative_loglik_2_par(theta[0], theta[1], n, suff_stats[:2]), 
                     (0,0), method='L-BFGS-B')
# Out:
#       fun: 16.01307269148557
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([5.61328761e-05, 1.68753900e-04])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 60
#       nit: 17
#    status: 0
#   success: True
#         x: array([14.02843197, -6.76681209])

# %%
theta_hat_2 = minimize(lambda theta: exp_family_negative_loglik_2_par(theta[0], theta[1], n, suff_stats[:2]), 
                     (0,0), method='L-BFGS-B')['x']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pdf = lambda df: np.exp((np.dot(df, theta_hat) - 
                         psi_func(theta_hat[0], theta_hat[1], theta_hat[2], theta_hat[3], 
                             theta_hat[4], theta_hat[5], theta_hat[6])))

# %%
pdf_2 = lambda df: np.exp((np.dot(df, theta_hat_2) - 
                         psi_2p_func(theta_hat_2[0], theta_hat_2[1])))

# %%
x_grid = pd.DataFrame({'gfr':np.linspace(0.4,2.1, 200), 
                       'gfr_2':(np.linspace(0.4,2.1, 200)) ** 2,
                       'gfr_3':(np.linspace(0.4,2.1, 200)) ** 3,
                       'gfr_4':(np.linspace(0.4,2.1, 200)) ** 4,
                       'gfr_5':(np.linspace(0.4,2.1, 200)) ** 5,
                       'gfr_6':(np.linspace(0.4,2.1, 200)) ** 6,
                       'gfr_7':(np.linspace(0.4,2.1, 200)) ** 7,
                      })
x_grid
# Out:
#           gfr     gfr_2     gfr_3      gfr_4      gfr_5      gfr_6       gfr_7
# 0    0.400000  0.160000  0.064000   0.025600   0.010240   0.004096    0.001638
# 1    0.408543  0.166907  0.068189   0.027858   0.011381   0.004650    0.001900
# 2    0.417085  0.173960  0.072556   0.030262   0.012622   0.005264    0.002196
# 3    0.425628  0.181159  0.077107   0.032819   0.013969   0.005945    0.002531
# 4    0.434171  0.188504  0.081843   0.035534   0.015428   0.006698    0.002908
# ..        ...       ...       ...        ...        ...        ...         ...
# 195  2.065829  4.267650  8.816236  18.212837  37.624610  77.726015  160.568667
# 196  2.074372  4.303019  8.926061  18.515969  38.409005  79.674560  165.274665
# 197  2.082915  4.338533  9.036794  18.822870  39.206429  81.663643  170.098392
# 198  2.091457  4.374194  9.148439  19.133569  40.017043  83.693937  175.042294
# 199  2.100000  4.410000  9.261000  19.448100  40.841010  85.766121  180.108854
#
# [200 rows x 7 columns]

# %%
pdf_vals = x_grid.apply(pdf, axis=1)
pdf_vals_2p = x_grid[['gfr', 'gfr_2']].apply(pdf_2, axis=1)
pdf_vals
# Out:
# 0      0.007845
# 1      0.009312
# 2      0.011026
# 3      0.013021
# 4      0.015337
#          ...
# 195    0.118273
# 196    0.127650
# 197    0.138410
# 198    0.150796
# 199    0.165103
# Length: 200, dtype: float64

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1,1,1)
ax.plot((np.linspace(0.4,2.1, 200)), pdf_vals, '-k')
ax.plot((np.linspace(0.4,2.1, 200)), pdf_vals_2p, 'or')
ax.hist(gfr_data['gfr'], bins, width=0.08, density=True)
ax.legend(['7-Parameter Exponential Family', 'Normal', 'Histogram'])
